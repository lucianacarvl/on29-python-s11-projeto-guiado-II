# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Song.csv")
df
# Out:
#                        Artist                              Title  Year  \
# 0     Bill Haley & his Comets              Rock Around the Clock  1955
# 1                 Celine Dion                My Heart Will Go On  1998
# 2             Sinead O'Connor               Nothing Compares 2 U  1990
# 3                 The Beatles                           Hey Jude  1968
# 4                 Bryan Adams  (Everything I Do) I Do it For You  1991
# ...                       ...                                ...   ...
# 4845                  Rihanna       If It's Lovin' That You Want  2005
# 4846                Al Jolson                          All Alone  1925
# 4847                   Sailor                Girls, Girls, Girls  1976
# 4848             Inner Circle                  Games People Play  1994
# 4849                  The Who                    See Me, Feel Me  1970
#
#        Sales  Streams  Downloads  RadioPlays  Rating
# 0     36.503   19.961      7.458       5.663   0.760
# ...

# %%
df.shape
# Out:
# (4850, 8)

# %%
df_backup = df.copy()

# %%
df.columns
# Out:
# Index(['Artist', 'Title', 'Year', 'Sales', 'Streams', 'Downloads',
#        'RadioPlays', 'Rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Artist         object
# Title          object
# Year            int64
# Sales         float64
# Streams       float64
# Downloads     float64
# RadioPlays    float64
# Rating        float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4850 entries, 0 to 4849
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Artist      4850 non-null   object
#  1   Title       4850 non-null   object
#  2   Year        4850 non-null   int64
#  3   Sales       4850 non-null   float64
#  4   Streams     4850 non-null   float64
#  5   Downloads   4850 non-null   float64
#  6   RadioPlays  4850 non-null   float64
#  7   Rating      4850 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 303.3+ KB

# %%
df.describe()
# Out:
#               Year        Sales      Streams    Downloads   RadioPlays  \
# count  4850.000000  4850.000000  4850.000000  4850.000000  4850.000000
# mean   1979.861443     8.154870     4.628823     2.970114     3.985120
# std      19.759676     4.555715     3.273776     2.668744     4.354419
# min    1901.000000     4.149000     0.000000     0.000000     0.000000
# 25%    1967.000000     5.069250     2.351250     1.039500     0.600000
# 50%    1981.000000     6.438000     4.200000     2.200000     2.570000
# 75%    1996.000000     9.784000     6.307000     4.183750     5.884000
# max    2014.000000    36.503000    25.545000    19.780000    24.393000
#
#             Rating
# count  4850.000000
# mean      0.481876
# std       0.624719
# min       0.000000
# 25%       0.000000
# 50%       0.512000
# 75%       0.571000
# max       4.460000

# %%
def processamento_df(df):
    head = df.head(3)
    
    baby_df = df.sample(100)
    
    df = df.sort_values("Year")
    
    #df_titanic = df.drop(["SibSp", "Parch"], axis = "columns")
    
    df = df.dropna()
    
    df = df.reset_index(drop=True)
    
    metricas = df.describe()
    
    return head, baby_df, df, metricas
df
# Out:
#                        Artist                              Title  Year  \
# 0     Bill Haley & his Comets              Rock Around the Clock  1955
# 1                 Celine Dion                My Heart Will Go On  1998
# 2             Sinead O'Connor               Nothing Compares 2 U  1990
# 3                 The Beatles                           Hey Jude  1968
# 4                 Bryan Adams  (Everything I Do) I Do it For You  1991
# ...                       ...                                ...   ...
# 4845                  Rihanna       If It's Lovin' That You Want  2005
# 4846                Al Jolson                          All Alone  1925
# 4847                   Sailor                Girls, Girls, Girls  1976
# 4848             Inner Circle                  Games People Play  1994
# 4849                  The Who                    See Me, Feel Me  1970
#
#        Sales  Streams  Downloads  RadioPlays  Rating
# 0     36.503   19.961      7.458       5.663   0.760
# ...

# %%
head, baby_df, df, metricas = processamento_df(df)

# %%
import csv
import sqlite3

# %%
file = open("Song.csv")

# %%
conteudo = csv.reader(file)

# %%
conn = sqlite3.connect("Song.db")

# %%
cursor = conn.cursor()

# %%
def criar_db():
    conn = sqlite3.connect("Song.db")
    cursor = conn.cursor()
    cursor.execute("""CREATE TABLE IF NOT EXISTS Song(
        Artist VARCHAR NOT NULL,
        Title VARCHAR NOT NULL,
        Year INT NOT NULL,
        Sales FLOAT NOT NULL,
        Streams FLOAT NOT NULL,
        Downloads FLOAT NOT NULL,
        RadioPlays FLOAT NOT NULL,
        Rating FLOAT);
""")
criar_db()

# %%
def importar_csv():
    conn = sqlite3.connect("Song.db")
    cursor = conn.cursor()
    
    with open('Song.csv', newline='', encoding='utf-8') as csvfile:
        leitor = csv.reader(csvfile)
        next(leitor)
        for linha in leitor:
            cursor.execute("INSERT INTO Song (Artist, Title, Year, Sales, Streams, Downloads, RadioPlays, Rating) VALUES (?, ?, ?, ?, ?, ?, ?, ?)", (linha[0], linha[1], linha[2], linha[3], linha[4], linha[5], linha[6], linha[7]))
            cursor.execute("SELECT * FROM Song")
    conn.commit()
    cursor.close()
    conn.close()
importar_csv()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 15
#      13     conn.close()
#      14 importar_csv()
# ---> 15 print(linha)
#
# NameError: name 'linha' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 for linha in leitor:
#       2     print(linha)
#
# NameError: name 'leitor' is not defined
