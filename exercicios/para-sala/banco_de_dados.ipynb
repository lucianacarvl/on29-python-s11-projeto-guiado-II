# %% [markdown]
# Importação de Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_titanic = pd.read_csv("titanic.csv")

# %%
contagem_passageiros = df_titanic["Pclass"].value_counts()
contagem_passageiros.plot(kind = "bar", edgecolor = "blue", color = "pink")

plt.xlabel("Classe do Passageiro")
plt.ylabel("Quantidade")
plt.title("Numero de Passageiros por classe")
# Out:
# Text(0.5, 1.0, 'Numero de Passageiros por classe')

# %%
#Taxa de Sobrevivência por Sexo

taxa_sob_sexo = df_titanic.groupby("Sex")["Survived"].mean()
taxa_sob_sexo.plot.bar(edgecolor="blue", color="pink")

plt.xlabel("Sexo")
plt.ylabel("Taxa de Sobrevivência")
plt.title("Taxa de Sobrevivência por Sexo")

plt.show()

# %%
#Distribuição de Idade

df_titanic["Age"].plot.hist(bins=10, edgecolor="blue", color="pink")

plt.xlabel("Idade")
plt.ylabel("Quantidade")
plt.title("Distribuição de Idade")
# Out:
# Text(0.5, 1.0, 'Distribuição de Idade')
